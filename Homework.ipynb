# %% [markdown]
# <a href="https://colab.research.google.com/github/kettesakchhorn/test/blob/master/Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/datasets/world-religion-projections/master/rounded_percentage.csv")
dataset.head(5)
# Out:
#    Year                    Region         Country  Buddhists  Christians  \
# 0  2010                     World   All Countries        7.1        31.4
# 1  2010             North America   All Countries        1.1        77.4
# 2  2010   Latin America-Caribbean   All Countries        1.0        90.0
# 3  2010                    Europe   All Countries        1.0        74.5
# 4  2010  Middle East-North Africa   All Countries        1.0         3.7
#
#    Folk Religions  Hindus  Jews  Muslims  Other Religions  Unaffiliated
# 0             5.9    15.0   1.0     23.2              1.0          16.4
# 1             1.0     1.0   1.8      1.0              1.0          17.1
# 2             1.7     1.0   1.0      1.0              1.0           7.7
# 3             1.0     1.0   1.0      5.9              1.0          18.8
# 4             1.0     1.0   1.6     93.0              1.0           1.0

# %%
dataset.shape
# Out:
# (1205, 11)

# %%
dataset.describe()
# Out:
#               Year    Buddhists   Christians  Folk Religions       Hindus  \
# count  1205.000000  1205.000000  1205.000000     1205.000000  1205.000000
# mean   2030.000000     4.108382    59.671286        3.186473     2.835104
# std      14.148007    13.169095    37.111985        7.233636     8.557906
# min    2010.000000     1.000000     1.000000        1.000000     1.000000
# 25%    2020.000000     1.000000    13.700000        1.000000     1.000000
# 50%    2030.000000     1.000000    76.600000        1.000000     1.000000
# 75%    2040.000000     1.000000    91.800000        1.700000     1.000000
# max    2050.000000    96.900000    99.000000       58.900000    80.700000
#
#               Jews      Muslims  Other Religions  Unaffiliated
# count  1205.000000  1205.000000      1205.000000   1205.000000
# mean      1.312365    23.192863         1.273527      8.616763
# std       4.604011    35.478585         1.463965     12.976296
# ...

# %%
numerical_variable = dataset.columns[dataset.dtypes !=  'object']
dataset[numerical_variable].head(5)
# Out:
#    Year  Buddhists  Christians  Folk Religions  Hindus  Jews  Muslims  \
# 0  2010        7.1        31.4             5.9    15.0   1.0     23.2
# 1  2010        1.1        77.4             1.0     1.0   1.8      1.0
# 2  2010        1.0        90.0             1.7     1.0   1.0      1.0
# 3  2010        1.0        74.5             1.0     1.0   1.0      5.9
# 4  2010        1.0         3.7             1.0     1.0   1.6     93.0
#
#    Other Religions  Unaffiliated
# 0              1.0          16.4
# 1              1.0          17.1
# 2              1.0           7.7
# 3              1.0          18.8
# 4              1.0           1.0

# %%
categorical_variable = dataset.columns[dataset.dtypes ==  'object']
dataset[categorical_variable].head(5)
# Out:
#                      Region         Country
# 0                     World   All Countries
# 1             North America   All Countries
# 2   Latin America-Caribbean   All Countries
# 3                    Europe   All Countries
# 4  Middle East-North Africa   All Countries

# %%
# Out:
#    Year  Buddhists  Christians  Folk Religions  Hindus  Jews  Muslims  \
# 0  2010        7.1        31.4             5.9    15.0   1.0     23.2
# 1  2010        1.1        77.4             1.0     1.0   1.8      1.0
# 2  2010        1.0        90.0             1.7     1.0   1.0      1.0
# 3  2010        1.0        74.5             1.0     1.0   1.0      5.9
# 4  2010        1.0         3.7             1.0     1.0   1.6     93.0
#
#    Other Religions  Unaffiliated
# 0              1.0          16.4
# 1              1.0          17.1
# 2              1.0           7.7
# 3              1.0          18.8
# 4              1.0           1.0

# %%
dataset.isnull().head(5)
# Out:
#     Year  Region  Country  Buddhists  Christians  Folk Religions  Hindus  \
# 0  False   False    False      False       False           False   False
# 1  False   False    False      False       False           False   False
# 2  False   False    False      False       False           False   False
# 3  False   False    False      False       False           False   False
# 4  False   False    False      False       False           False   False
#
#     Jews  Muslims  Other Religions  Unaffiliated
# 0  False    False            False         False
# 1  False    False            False         False
# 2  False    False            False         False
# 3  False    False            False         False
# 4  False    False            False         False

# %%
len(dataset)
# Out:
# 1205

# %%
dataset[numerical_variable].isnull().sum()/len(dataset)
# Out:
# Year               0.0
# Buddhists          0.0
# Christians         0.0
# Folk Religions     0.0
# Hindus             0.0
# Jews               0.0
# Muslims            0.0
# Other Religions    0.0
# Unaffiliated       0.0
# dtype: float64

# %%
dataset.fillna('Year')
# Out:
#       Year                    Region                Country  Buddhists  \
# 0     2010                     World          All Countries        7.1
# 1     2010             North America          All Countries        1.1
# 2     2010   Latin America-Caribbean          All Countries        1.0
# 3     2010                    Europe          All Countries        1.0
# 4     2010  Middle East-North Africa          All Countries        1.0
# ...    ...                       ...                    ...        ...
# 1200  2050        Sub-Saharan Africa               Zimbabwe        1.0
# 1201  2050        Sub-Saharan Africa            South Sudan        1.0
# 1202  2050   Latin America-Caribbean                Curacao        1.0
# 1203  2050   Latin America-Caribbean           Sint Maarten        1.0
# 1204  2050   Latin America-Caribbean  Caribbean Netherlands        1.0
#
#       Christians  Folk Religions  Hindus  Jews  Muslims  Other Religions  \
# ...

# %%
dataset['Buddhists'].replace(1.0,'one').head(15)
# Out:
# 0      7.1
# 1      1.1
# 2      one
# 3      one
# 4      one
# 5      one
# 6     11.9
# 7      one
# 8      one
# 9      one
# 10     one
# 11     one
# 12     one
# 13     one
# 14     one
# Name: Buddhists, dtype: object

# %%
dataset.iloc[1:6]
# Out:
#    Year                    Region         Country  Buddhists  Christians  \
# 1  2010             North America   All Countries        1.1        77.4
# 2  2010   Latin America-Caribbean   All Countries        1.0        90.0
# 3  2010                    Europe   All Countries        1.0        74.5
# 4  2010  Middle East-North Africa   All Countries        1.0         3.7
# 5  2010        Sub-Saharan Africa   All Countries        1.0        62.9
#
#    Folk Religions  Hindus  Jews  Muslims  Other Religions  Unaffiliated
# 1             1.0     1.0   1.8      1.0              1.0          17.1
# 2             1.7     1.0   1.0      1.0              1.0           7.7
# 3             1.0     1.0   1.0      5.9              1.0          18.8
# 4             1.0     1.0   1.6     93.0              1.0           1.0
# 5             3.3     1.0   1.0     30.2              1.0           3.2

# %%
dataset = dataset.set_index(dataset['Country'])
dataset.loc['Cambodia']
# Out:
#           Year        Region   Country  Buddhists  Christians  Folk Religions  \
# Country
# Cambodia  2010  Asia-Pacific  Cambodia       96.9         1.0             1.0
# Cambodia  2020  Asia-Pacific  Cambodia       96.8         1.0             1.0
# Cambodia  2030  Asia-Pacific  Cambodia       96.8         1.0             1.0
# Cambodia  2040  Asia-Pacific  Cambodia       96.7         1.0             1.0
# Cambodia  2050  Asia-Pacific  Cambodia       96.7         1.0             1.0
#
#           Hindus  Jews  Muslims  Other Religions  Unaffiliated
# Country
# Cambodia     1.0   1.0      2.0              1.0           1.0
# Cambodia     1.0   1.0      2.0              1.0           1.0
# Cambodia     1.0   1.0      2.0              1.0           1.0
# Cambodia     1.0   1.0      2.0              1.0           1.0
# Cambodia     1.0   1.0      2.1              1.0           1.0

# %%
dataset.rename(columns={'Unaffiliated' : 'Athiest'}).head(5)
# Out:
#                 Year                    Region         Country  Buddhists  \
# Country
#  All Countries  2010                     World   All Countries        7.1
#  All Countries  2010             North America   All Countries        1.1
#  All Countries  2010   Latin America-Caribbean   All Countries        1.0
#  All Countries  2010                    Europe   All Countries        1.0
#  All Countries  2010  Middle East-North Africa   All Countries        1.0
#
#                 Christians  Folk Religions  Hindus  Jews  Muslims  \
# Country
#  All Countries        31.4             5.9    15.0   1.0     23.2
#  All Countries        77.4             1.0     1.0   1.8      1.0
#  All Countries        90.0             1.7     1.0   1.0      1.0
#  All Countries        74.5             1.0     1.0   1.0      5.9
#  All Countries         3.7             1.0     1.0   1.6     93.0
#
#                 Other Religions  Athiest
# Country
#  All Countries              1.0     16.4
# ...

# %%
print('Sum:', dataset['Jews'].max())
dataset
# Out:
# Sum: 75.6
#                        Year                    Region                Country  \
# Country
#  All Countries         2010                     World          All Countries
#  All Countries         2010             North America          All Countries
#  All Countries         2010   Latin America-Caribbean          All Countries
#  All Countries         2010                    Europe          All Countries
#  All Countries         2010  Middle East-North Africa          All Countries
# ...                     ...                       ...                    ...
# Zimbabwe               2050        Sub-Saharan Africa               Zimbabwe
# South Sudan            2050        Sub-Saharan Africa            South Sudan
# Curacao                2050   Latin America-Caribbean                Curacao
# Sint Maarten           2050   Latin America-Caribbean           Sint Maarten
# Caribbean Netherlands  2050   Latin America-Caribbean  Caribbean Netherlands
#
# ...

# %%
dataset.drop(dataset.columns[1], axis=1)
# Out:
#                        Year                Country  Buddhists  Christians  \
# Country
#  All Countries         2010          All Countries        7.1        31.4
#  All Countries         2010          All Countries        1.1        77.4
#  All Countries         2010          All Countries        1.0        90.0
#  All Countries         2010          All Countries        1.0        74.5
#  All Countries         2010          All Countries        1.0         3.7
# ...                     ...                    ...        ...         ...
# Zimbabwe               2050               Zimbabwe        1.0        86.1
# South Sudan            2050            South Sudan        1.0        60.5
# Curacao                2050                Curacao        1.0        93.9
# Sint Maarten           2050           Sint Maarten        1.0        93.9
# Caribbean Netherlands  2050  Caribbean Netherlands        1.0        93.9
#
# ...

# %%
dataset.drop([], axis =0)
# Out:
#                        Year                    Region                Country  \
# Country
#  All Countries         2010                     World          All Countries
#  All Countries         2010             North America          All Countries
#  All Countries         2010   Latin America-Caribbean          All Countries
#  All Countries         2010                    Europe          All Countries
#  All Countries         2010  Middle East-North Africa          All Countries
# ...                     ...                       ...                    ...
# Zimbabwe               2050        Sub-Saharan Africa               Zimbabwe
# South Sudan            2050        Sub-Saharan Africa            South Sudan
# Curacao                2050   Latin America-Caribbean                Curacao
# Sint Maarten           2050   Latin America-Caribbean           Sint Maarten
# Caribbean Netherlands  2050   Latin America-Caribbean  Caribbean Netherlands
#
# ...

# %%
dataset['Country'].unique()
# Out:
# array([' All Countries', 'Afghanistan', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia-Herzegovina', 'Botswana',
#        'Brazil', 'British Virgin Islands', 'Brunei', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada',
#        'Cape Verde', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Republic of the Congo', 'Democratic Republic of the Congo',
#        'Cook Islands', 'Costa Rica', 'Ivory Coast', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
# ...
